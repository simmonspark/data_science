# %% [markdown]
# # Matplotlib Library
# - matplotlib 의 구동방식
#   - Pyplot API: command 방식으로 함수 사용
#   - Object-oriented API: object-oriented library 직접 사용

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
from numpy.random import randn
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 간단한 matplotlib API

# %%
x = np.arange(10)
y = x**2
plt.plot(y)  # x-axis 는 by default 1,2,3,4...

# %%
x = np.linspace(0,1,50)
y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

# sizes are in inches, but the actual size of the figure on your screen
# or in a saved file can be affected by several factors, including the
# display resolution.

plt.figure(figsize=(6,3), dpi=100)
plt.plot(x,y1,'r-*',lw=1)
plt.plot(x,y2,'b--',lw=3)

# %% [markdown]
# ## 객체지향 API
# - figure 는 figure object
# - axes는 figure 내에서 축을 가지는 하나의 좌표평면과 같은 개념으로 실제로 데이터가 그려지는 곳은 axes이다.

# %%
x = np.linspace(0,1,50)
y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)


fig = plt.figure()          # 직접 Figure 객체를 생성
ax = fig.subplots()         # 직접 axes를 생성
ax.plot(x, y1, 'r-*', lw=1)    # 생성된 axes에 대한 plot() 멤버 직접 호출
ax.plot(x, y2, 'b--', lw=1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %% [markdown]
# ## Combine Figure and Axes using plt.subplots()

# %%
# 전체는 figure, 그 안의 그림들은 axes (axis 는 x, y-축 값 범위)
x = np.linspace(0,1,50)
y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

fig, ax = plt.subplots(1,2, figsize=(6,3))  # plt.subplots() 함수는 Figure 객체를 생성하고 Figure.subplots()를 호출하여 리턴
ax[0].plot(x,y1,'r-*',lw=1)
ax[1].plot(x,y2,'b--',lw=1)

# %% [markdown]
# # Multiple graphs
# - use subplot() function
# - object-oriented API

# %% [markdown]
# ## use plt.subplot() function
# - creates a single subplot within a grid layout.
# - simple and quick

# %%
x = np.linspace(0,1,50)

y1 = np.cos(4*np.pi*x)
y2 = np.cos(4*np.pi*x)*np.exp(-2*x)

plt.subplot(2,1,1)
plt.plot(x,y1,'r-*',lw=1)
plt.grid(True)
plt.ylabel(r'$sin(4 \pi x)$')
plt.axis([0,1,-1.5,1.5])

plt.subplot(2,1,2)
plt.plot(x,y2,'b--o',lw=1)
plt.grid(True)
plt.xlabel('x')
plt.ylabel(r'$ e^{-2x} sin(4\pi x) $')
plt.axis([0,1,-1.5,1.5])

plt.tight_layout()   # Adjust the padding between and around subplots.
plt.show()

# %% [markdown]
# ## plt.subplots() 사용
# - creates a figure and a grid of subplots in a single call.

# %%
fig,ax = plt.subplots(2,1)

ax[0].plot(x,y1,'r-*',lw=1)
ax[0].grid(True)
ax[0].set_ylabel(r'$sin(4 \pi x)$')
ax[0].axis([0,1,-1.5,1.5])

ax[1].plot(x,y2,'b--o',lw=1)
ax[1].grid(True)
ax[1].set_xlabel('x')
ax[1].set_ylabel(r'$ e^{-2x} sin(4\pi x) $')
ax[1].axis([0,1,-1.5,1.5])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Object-oriented API (add_subplot())
# - It is useful when you want to add subplots dynamically or in a more controlled manner.

# %%
fig = plt.figure(figsize=(6,4))

ax = fig.add_subplot(1,2,1)
ax.plot(x,y1,'r-*',lw=1)
ax.grid(True)
ax.set_ylabel(r'$sin(4 \pi x)$')
ax.axis([0,1,-1.5,1.5])

ax = fig.add_subplot(1,2,2)
ax.plot(x,y2,'b--o',lw=1)
ax.grid(True)
ax.set_xlabel('x')
ax.set_ylabel(r'$ e^{-2x} sin(4\pi x) $')
ax.axis([0,1,-1.5,1.5])

fig.tight_layout()
plt.show()

# %% [markdown]
# ## examples

# %%
# one more example
fig = plt.figure()     # Create a new figure, or activate an existing figure.

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.hist(np.random.randn(200), bins=20, color='k', rwidth=0.5)
ax2.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30))
ax3.plot(np.arange(10),np.random.randn(10))

# %%
# 같은 코드를 여러번 실행하면 그림이 겹침

ax1.hist(np.random.randn(200), bins=20, color='k', rwidth=0.5)
ax2.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30))
ax3.plot(np.arange(10),np.random.randn(10))
fig                # Create a new figure, or activate an existing figure.

# %%
fig, axes = plt.subplots(2,3, sharex=True, sharey=True)
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# ## subplot 주변의 공간 고정

# %%
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=None, hspace=None) # subplot 간의 간격을 조정하는 함수 _adjust()
# wspace, hspace: width and height between the subplots
# left, right, top, bottom: sides of the subplots

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.plot(randn(30), 'ko--') # 'o': circles, 's': squares, '^': triangles, etc.
                            # '--': dashed lines, '-': solid lines, ':': dotted lines, etc.

# %%
# 1000 개의 랜덤 넘버 (정규분포)의 누적 값을 그리는 예
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')    # cumulative sum (negative value 가 들어 있음)
ax.plot(randn(1000).cumsum(), 'b--', label='two')
ax.plot(randn(1000).cumsum(), 'r.', label='three')

ax.legend(loc='best')     # overlap 이 가장 적은 곳을 자동으로 찾아 위치

# %%
# for reference for cumsum() and sum()
arr = np.array([[1,2,3],[4,5,6]])
arr, arr.sum(), arr.cumsum()
# Out:
# (array([[1, 2, 3],
#         [4, 5, 6]]),
#  21,
#  array([ 1,  3,  6, 10, 15, 21]))

# %% [markdown]
# ## subplot 주석달기 및 그리는 방법

# %%
# 일반 도형을 그리는 함수도 제공
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.5, 0.2, color='k', alpha=0.1)
       ##(0.2,0.75) 사각형의 시작점 0.5 가로길이 0.2 세로길이를 뜻한다.
       ## alpha 색깔의 명도를 나타내준다 인수를 바꿔서 결과 변화를 확인해보자!

circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
       ## (0,7,0,2) 원의 중심 을 뜻한다 / 0.15 원의 반지름을 뜻한다.

pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], #꼭지점의 좌표
                   color='g', alpha=0.5)

ax.add_patch(rect) ## ax subplot에 도형을 추가한다.
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# # Series 나 DataFrame 으로부터 막대그라프 그리는 예
# - dataframe.plot(kind=' ')
# - series.plot(kind=' ')

# %%
fig, axes = plt.subplots(2, 1)
fig.set_size_inches(6,6)
data = Series(np.random.rand(16), index=list('abcdefghijklmnop'))

data.plot(kind='bar', ax=axes[0], color='k', alpha=0.5)  # alpha-transparency
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.9)
# Out:
# <Axes: >

# %%
df = DataFrame(np.random.rand(6, 4),
               index=['KIm', 'Choi', 'Park', 'Lee', 'Goo', 'Jeong'],
               columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# KIm    0.832270  0.980038  0.629797  0.255818
# Choi   0.647388  0.704664  0.499076  0.460181
# Park   0.951514  0.582653  0.225266  0.893478
# Lee    0.662299  0.799567  0.775673  0.694221
# Goo    0.898677  0.664144  0.713345  0.158354
# Jeong  0.594393  0.657660  0.952669  0.978613

# %%
df.plot(kind='bar', rot=0)
# Out:
# <Axes: >

# %%
df.plot(kind='barh', stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 히스토그램 및 밀도(density) 그래프

# %%
np.random.seed(42)
comp1 = np.random.normal(0, 1, size=200)  # N(0, 1), same as randn()
comp2 = np.random.normal(10, 2, size=200)  # N(10, 2), same as 10 + 2*randn()
values = Series(np.concatenate([comp1, comp2])) #concat(1,2) -1번째 문자열에 두번째 문자열을 합치는 함수와 동일
values.hist(bins=100, alpha=0.3, color='k', density=True)
values.plot(kind='kde', style='k--')
# kde (kernel density estimation - 히스토그램으로부터 확률빌도함수(PDF) 추정)
# Out:
# <Axes: ylabel='Density'>
